# %% [markdown]
# <a href="https://colab.research.google.com/github/idanh8/IoT_project_accelerometer_data/blob/main/activity_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imports and Setup

# %%
import pandas as pd
import numpy as np
import zipfile
import io
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
import pickle

# %% [markdown]
# Utility Functions

# %%
def norm(x, y, z):
  return (x**2 + y**2 + z**2)**0.5

# %%
def process_raw(zip_path):
  count = 0
  datasets = {}
  with zipfile.ZipFile(zip_path, 'r') as z:
    for file_name in z.namelist():
      if file_name == '8_walk_4_3.csv':
        continue
      file_data = {}
      count += 1
      csv_data = z.read(file_name)

      header = csv_data.decode().split('\n')[:5]
      header = [item.lower() for item in header]
      header = [item.replace('"', '') for item in header]
      rows = csv_data.decode().split('\n')[5:]
      df = pd.read_csv(io.StringIO('\n'.join(rows)))
      activity = 0 if ('walk' in header[0] or 'walking' in header[2]) else 1
      steps = int(header[3].split(',')[1])


      file_data.update([('Name', file_name),('Data', df), ('Steps', steps), ('Activity', activity)])
      exec(f"datasets[{count-1}] = file_data")
  print(f'There are {count} files in the dataset')
  problems = ['11_walk_5_1.csv', '6_run_3_1.csv', '6_run_4_1.csv','11_walk_1_1.csv', '11_walk_2_1.csv', '11_walk_3_1.csv', '6_walk_5_1.csv']
  for dataset in datasets.values():
    if dataset['Name'] in problems:
      df = dataset['Data']
      df = df.drop(0)
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    if dataset['Name'] == '16_run_3_1.csv':
      df = dataset['Data']
      df = df.drop(106)
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    if dataset['Name'] == '1_walk_4_1.csv':
      df = dataset['Data']
      df = df[:995]
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    if dataset['Name'] == '31_walk_2_1.csv':
      df = dataset['Data']
      df = df.drop(207)
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    if dataset['Name'] == '4_run_2_2.csv':
      df = dataset['Data']
      df = df.drop(185)
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    if dataset['Name'] == '4_walk_1_3.csv':
      df = dataset['Data']
      df = df.drop(368)
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    if dataset['Name'] == '4_walk_2_3.csv':
      df = dataset['Data']
      df = df.drop(95)
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    if dataset['Name'] == '4_walk_4_2.csv':
      df = dataset['Data']
      df = df.drop(599)
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    if dataset['Name'] == '4_walk_3_2.csv':
      df = dataset['Data']
      df = df.drop(39)
      df = df.drop(41)
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    if dataset['Name'] == '5_run_3_1.csv':
      df = dataset['Data']
      df = df.drop(352)
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    if dataset['Name'] == '8_run_3_1.csv':
      df = dataset['Data']
      df = df.drop(264)
      df = df.drop(605)
      df = df.drop(606)
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    if dataset['Name'] == '8_run_3_1.csv':
      df = dataset['Data']
      df = df.drop(603)
      df = df.drop(604)
      df = df.drop(605)
      df = df.reset_index(drop=True)
      dataset['Data'] = df
    df = dataset['Data']
    df['Norm'] = df.apply(lambda row: norm(float(row[1]), float(row[2]), float(row[3])), axis =1)
  return datasets

# %%
class Model(nn.Module):
    def __init__(self, input_size, output_size):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(input_size, 16)
        self.relu = nn.ReLU()
        self.lrelu = nn.LeakyReLU()
        self.fc2 = nn.Linear(16, 8)
        self.fc3 = nn.Linear(8, output_size)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.lrelu(out)
        out = self.fc3(out)
        out = self.sigmoid(out)
        return out

# %%
def generate_dataset(dataset):
    data = []
    df = dataset['Data']
    df['Norm'] = df.apply(lambda row: norm(float(row[1]), float(row[2]), float(row[3])), axis =1)
    steps = dataset['Steps']
    act = dataset['Activity']
    slices = np.arange(0, len(df), 7)
    for sliver in slices:
      if (sliver + 7) > len(df):
        continue
      sliver = df.loc[sliver:sliver+6]
      acc = np.array(sliver.iloc[:, [1, 2, 3, 4]].values, dtype='float32')
      flat = torch.tensor(acc.reshape(1, -1))
      data.append(flat)
    stacked = torch.stack(data).to(torch.float32)
    label_tensor = torch.ones(stacked.shape[0])
    final_dataset = TensorDataset(stacked, label_tensor)
    return final_dataset, stacked.shape[0]

# %%
def predict(model, data):
    outcomes = []
    i = 0
    for dataset in data.values():
        i += 1
        testset, batch_size = generate_dataset(dataset)
        true_label = dataset['Activity']
        dataloader = DataLoader(testset, batch_size=batch_size, shuffle=True)
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        model.eval()
        with torch.no_grad():
          for batch in dataloader:
              batch_tensor, batch_labels = batch
              batch_tensor = batch_tensor.to(device)
              batch_labels = batch_labels.to(device)
              output = model(batch_tensor)
              predicted_class = torch.round(output).squeeze(dim=1)
              final_pred = 0 if predicted_class.mean() < 0.5 else 1
              acc = 1 if final_pred == true_label else 0
              activity = 'Walking' if final_pred == 0 else 'Running'
              label = 'Walking' if true_label == 0 else 'Running'
              print(f'Dataset {i}: True: {label}, Predicted: {activity}')
        outcomes.append(acc)
    print(f'Final Accuracy: {sum(outcomes)/len(outcomes)}')

# %% [markdown]
# Predictions

# %%
zip_path = 'data_set.zip' # change accordingly, please ensure a zipfile is passed containing csv files in the correct format
data = process_raw(zip_path)
model = pickle.load(open('activity_net.pkl', 'rb'))
predict(model, data)
# Out:
# There are 243 files in the dataset
# Dataset 1: True: Running, Predicted: Running
# Dataset 2: True: Running, Predicted: Walking
# Dataset 3: True: Running, Predicted: Running
# Dataset 4: True: Running, Predicted: Running
# Dataset 5: True: Running, Predicted: Running
# Dataset 6: True: Walking, Predicted: Walking
# Dataset 7: True: Walking, Predicted: Walking
# Dataset 8: True: Walking, Predicted: Walking
# Dataset 9: True: Walking, Predicted: Walking
# Dataset 10: True: Walking, Predicted: Walking
# Dataset 11: True: Running, Predicted: Running
# Dataset 12: True: Running, Predicted: Running
# Dataset 13: True: Running, Predicted: Running
# Dataset 14: True: Running, Predicted: Running
# Dataset 15: True: Running, Predicted: Running
# Dataset 16: True: Walking, Predicted: Walking
# Dataset 17: True: Walking, Predicted: Walking
# Dataset 18: True: Walking, Predicted: Walking
# Dataset 19: True: Walking, Predicted: Walking
# Dataset 20: True: Walking, Predicted: Walking
# Dataset 21: True: Running, Predicted: Running
# Dataset 22: True: Running, Predicted: Running
# Dataset 23: True: Running, Predicted: Running
# Dataset 24: True: Running, Predicted: Running
# Dataset 25: True: Running, Predicted: Running
# Dataset 26: True: Walking, Predicted: Walking
# Dataset 27: True: Walking, Predicted: Walking
# Dataset 28: True: Walking, Predicted: Walking
# Dataset 29: True: Walking, Predicted: Walking
# Dataset 30: True: Walking, Predicted: Walking
# Dataset 31: True: Running, Predicted: Walking
# Dataset 32: True: Running, Predicted: Running
# Dataset 33: True: Running, Predicted: Running
# Dataset 34: True: Running, Predicted: Running
# Dataset 35: True: Running, Predicted: Running
# Dataset 36: True: Walking, Predicted: Walking
# Dataset 37: True: Walking, Predicted: Walking
# Dataset 38: True: Walking, Predicted: Walking
# Dataset 39: True: Walking, Predicted: Walking
# Dataset 40: True: Walking, Predicted: Walking
# Dataset 41: True: Running, Predicted: Running
# Dataset 42: True: Running, Predicted: Running
# Dataset 43: True: Running, Predicted: Running
# Dataset 44: True: Running, Predicted: Running
# Dataset 45: True: Running, Predicted: Running
# Dataset 46: True: Walking, Predicted: Walking
# Dataset 47: True: Walking, Predicted: Walking
# Dataset 48: True: Walking, Predicted: Walking
# Dataset 49: True: Walking, Predicted: Walking
# Dataset 50: True: Walking, Predicted: Walking
# Dataset 51: True: Running, Predicted: Running
# Dataset 52: True: Running, Predicted: Running
# Dataset 53: True: Running, Predicted: Running
# Dataset 54: True: Running, Predicted: Running
# Dataset 55: True: Running, Predicted: Running
# Dataset 56: True: Walking, Predicted: Walking
# Dataset 57: True: Walking, Predicted: Walking
# Dataset 58: True: Walking, Predicted: Walking
# Dataset 59: True: Walking, Predicted: Walking
# Dataset 60: True: Walking, Predicted: Walking
# Dataset 61: True: Running, Predicted: Running
# Dataset 62: True: Running, Predicted: Running
# Dataset 63: True: Running, Predicted: Running
# Dataset 64: True: Running, Predicted: Running
# Dataset 65: True: Walking, Predicted: Walking
# Dataset 66: True: Walking, Predicted: Walking
# Dataset 67: True: Walking, Predicted: Walking
# Dataset 68: True: Walking, Predicted: Walking
# Dataset 69: True: Walking, Predicted: Walking
# Dataset 70: True: Running, Predicted: Running
# Dataset 71: True: Running, Predicted: Running
# Dataset 72: True: Running, Predicted: Running
# Dataset 73: True: Running, Predicted: Running
# Dataset 74: True: Walking, Predicted: Walking
# Dataset 75: True: Walking, Predicted: Walking
# Dataset 76: True: Walking, Predicted: Walking
# Dataset 77: True: Walking, Predicted: Walking
# Dataset 78: True: Walking, Predicted: Walking
# Dataset 79: True: Running, Predicted: Running
# Dataset 80: True: Running, Predicted: Running
# Dataset 81: True: Running, Predicted: Running
# Dataset 82: True: Running, Predicted: Running
# Dataset 83: True: Running, Predicted: Running
# Dataset 84: True: Walking, Predicted: Walking
# Dataset 85: True: Walking, Predicted: Walking
# Dataset 86: True: Walking, Predicted: Walking
# Dataset 87: True: Walking, Predicted: Walking
# Dataset 88: True: Running, Predicted: Running
# Dataset 89: True: Running, Predicted: Running
# Dataset 90: True: Running, Predicted: Running
# Dataset 91: True: Running, Predicted: Running
# Dataset 92: True: Running, Predicted: Running
# Dataset 93: True: Walking, Predicted: Walking
# Dataset 94: True: Walking, Predicted: Walking
# Dataset 95: True: Walking, Predicted: Walking
# Dataset 96: True: Walking, Predicted: Walking
# Dataset 97: True: Walking, Predicted: Running
# Dataset 98: True: Running, Predicted: Running
# Dataset 99: True: Running, Predicted: Running
# Dataset 100: True: Running, Predicted: Running
# Dataset 101: True: Running, Predicted: Running
# Dataset 102: True: Running, Predicted: Running
# Dataset 103: True: Walking, Predicted: Walking
# Dataset 104: True: Walking, Predicted: Walking
# Dataset 105: True: Walking, Predicted: Walking
# Dataset 106: True: Walking, Predicted: Walking
# Dataset 107: True: Walking, Predicted: Walking
# Dataset 108: True: Running, Predicted: Running
# Dataset 109: True: Running, Predicted: Running
# Dataset 110: True: Running, Predicted: Running
# Dataset 111: True: Running, Predicted: Running
# Dataset 112: True: Running, Predicted: Running
# Dataset 113: True: Walking, Predicted: Walking
# Dataset 114: True: Walking, Predicted: Walking
# Dataset 115: True: Walking, Predicted: Walking
# Dataset 116: True: Walking, Predicted: Walking
# Dataset 117: True: Walking, Predicted: Walking
# Dataset 118: True: Running, Predicted: Running
# Dataset 119: True: Running, Predicted: Running
# Dataset 120: True: Running, Predicted: Running
# Dataset 121: True: Running, Predicted: Running
# Dataset 122: True: Running, Predicted: Running
# Dataset 123: True: Walking, Predicted: Walking
# Dataset 124: True: Walking, Predicted: Walking
# Dataset 125: True: Walking, Predicted: Walking
# Dataset 126: True: Walking, Predicted: Walking
# Dataset 127: True: Walking, Predicted: Walking
# Dataset 128: True: Running, Predicted: Running
# Dataset 129: True: Running, Predicted: Running
# Dataset 130: True: Running, Predicted: Running
# Dataset 131: True: Running, Predicted: Running
# Dataset 132: True: Running, Predicted: Running
# Dataset 133: True: Walking, Predicted: Walking
# Dataset 134: True: Walking, Predicted: Walking
# Dataset 135: True: Walking, Predicted: Walking
# Dataset 136: True: Walking, Predicted: Walking
# Dataset 137: True: Walking, Predicted: Walking
# Dataset 138: True: Running, Predicted: Running
# Dataset 139: True: Running, Predicted: Running
# Dataset 140: True: Running, Predicted: Running
# Dataset 141: True: Running, Predicted: Running
# Dataset 142: True: Running, Predicted: Running
# Dataset 143: True: Walking, Predicted: Walking
# Dataset 144: True: Walking, Predicted: Walking
# Dataset 145: True: Walking, Predicted: Walking
# Dataset 146: True: Walking, Predicted: Walking
# Dataset 147: True: Walking, Predicted: Walking
# Dataset 148: True: Running, Predicted: Running
# Dataset 149: True: Running, Predicted: Running
# Dataset 150: True: Running, Predicted: Running
# Dataset 151: True: Running, Predicted: Running
# Dataset 152: True: Running, Predicted: Running
# Dataset 153: True: Walking, Predicted: Walking
# Dataset 154: True: Walking, Predicted: Walking
# Dataset 155: True: Walking, Predicted: Walking
# Dataset 156: True: Walking, Predicted: Walking
# Dataset 157: True: Running, Predicted: Running
# Dataset 158: True: Running, Predicted: Running
# Dataset 159: True: Running, Predicted: Running
# Dataset 160: True: Running, Predicted: Running
# Dataset 161: True: Running, Predicted: Running
# Dataset 162: True: Walking, Predicted: Walking
# Dataset 163: True: Walking, Predicted: Walking
# Dataset 164: True: Walking, Predicted: Walking
# Dataset 165: True: Walking, Predicted: Walking
# Dataset 166: True: Running, Predicted: Running
# Dataset 167: True: Running, Predicted: Running
# Dataset 168: True: Running, Predicted: Running
# Dataset 169: True: Running, Predicted: Running
# Dataset 170: True: Running, Predicted: Running
# Dataset 171: True: Walking, Predicted: Walking
# Dataset 172: True: Walking, Predicted: Walking
# Dataset 173: True: Walking, Predicted: Walking
# Dataset 174: True: Walking, Predicted: Walking
# Dataset 175: True: Walking, Predicted: Walking
# Dataset 176: True: Running, Predicted: Running
# Dataset 177: True: Running, Predicted: Running
# Dataset 178: True: Running, Predicted: Running
# Dataset 179: True: Running, Predicted: Running
# Dataset 180: True: Running, Predicted: Running
# Dataset 181: True: Walking, Predicted: Walking
# Dataset 182: True: Walking, Predicted: Walking
# Dataset 183: True: Walking, Predicted: Walking
# Dataset 184: True: Walking, Predicted: Walking
# Dataset 185: True: Walking, Predicted: Walking
# Dataset 186: True: Running, Predicted: Running
# Dataset 187: True: Running, Predicted: Running
# Dataset 188: True: Running, Predicted: Running
# Dataset 189: True: Running, Predicted: Running
# Dataset 190: True: Running, Predicted: Running
# Dataset 191: True: Walking, Predicted: Walking
# Dataset 192: True: Walking, Predicted: Walking
# Dataset 193: True: Walking, Predicted: Walking
# Dataset 194: True: Walking, Predicted: Walking
# Dataset 195: True: Walking, Predicted: Walking
# Dataset 196: True: Running, Predicted: Running
# Dataset 197: True: Running, Predicted: Running
# Dataset 198: True: Running, Predicted: Running
# Dataset 199: True: Running, Predicted: Running
# Dataset 200: True: Running, Predicted: Running
# Dataset 201: True: Walking, Predicted: Walking
# Dataset 202: True: Walking, Predicted: Walking
# Dataset 203: True: Walking, Predicted: Walking
# Dataset 204: True: Walking, Predicted: Walking
# Dataset 205: True: Walking, Predicted: Walking
# Dataset 206: True: Running, Predicted: Running
# Dataset 207: True: Running, Predicted: Running
# Dataset 208: True: Running, Predicted: Running
# Dataset 209: True: Walking, Predicted: Running
# Dataset 210: True: Walking, Predicted: Walking
# Dataset 211: True: Walking, Predicted: Walking
# Dataset 212: True: Walking, Predicted: Walking
# Dataset 213: True: Walking, Predicted: Walking
# Dataset 214: True: Walking, Predicted: Walking
# Dataset 215: True: Running, Predicted: Running
# Dataset 216: True: Running, Predicted: Running
# Dataset 217: True: Running, Predicted: Running
# Dataset 218: True: Running, Predicted: Running
# Dataset 219: True: Running, Predicted: Running
# Dataset 220: True: Walking, Predicted: Walking
# Dataset 221: True: Walking, Predicted: Walking
# Dataset 222: True: Walking, Predicted: Walking
# Dataset 223: True: Walking, Predicted: Walking
# Dataset 224: True: Walking, Predicted: Walking
# Dataset 225: True: Running, Predicted: Running
# Dataset 226: True: Running, Predicted: Running
# Dataset 227: True: Running, Predicted: Running
# Dataset 228: True: Running, Predicted: Running
# Dataset 229: True: Running, Predicted: Running
# Dataset 230: True: Walking, Predicted: Walking
# Dataset 231: True: Walking, Predicted: Walking
# Dataset 232: True: Walking, Predicted: Walking
# Dataset 233: True: Walking, Predicted: Walking
# Dataset 234: True: Running, Predicted: Running
# Dataset 235: True: Running, Predicted: Running
# Dataset 236: True: Running, Predicted: Running
# Dataset 237: True: Running, Predicted: Running
# Dataset 238: True: Running, Predicted: Running
# Dataset 239: True: Walking, Predicted: Walking
# Dataset 240: True: Walking, Predicted: Walking
# Dataset 241: True: Walking, Predicted: Walking
# Dataset 242: True: Walking, Predicted: Walking
# Dataset 243: True: Walking, Predicted: Walking
# Final Accuracy: 0.9835390946502057
